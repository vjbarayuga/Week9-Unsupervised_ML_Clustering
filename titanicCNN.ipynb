# %% [markdown]
# <a href="https://colab.research.google.com/github/vjbarayuga/Week9-Unsupervised_ML_Clustering/blob/main/titanicCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Network with Keras for Kaggle's Titanic Dataset

# %%
# import google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# ignore Deprecation Warning
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

# Neural Network
import keras 
from keras.models import Sequential 
from keras.layers import Dense

# load the data
df_train = pd.read_csv('/content/drive/MyDrive/Coding_DOJO-Data_Science_Bootcamp/04_AdvancedML/Titanic Dataset/train.csv')
df_test = pd.read_csv('/content/drive/MyDrive/Coding_DOJO-Data_Science_Bootcamp/04_AdvancedML/Titanic Dataset/test.csv')
df = df_train.append(df_test , ignore_index = True)

# some quick inspections
print(df_train.shape, df_test.shape, df_train.columns.values)
# Out:
# (891, 12) (418, 11) ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %% [markdown]
# ## Data Preprocessing
# Let's look at individual features one by one. Missing values will have to be filled. Categorical features need to be transformed to numerical values.

# %% [markdown]
# ### Pclass

# %%
# check if there is any NAN
df['Pclass'].isnull().sum(axis=0)
# Out:
# 0

# %%
# inspect the correlation between Pclass and Survived
df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %% [markdown]
# We can see that a higher class (lower value) has a higher survival rate. This should be a very useful feature.

# %% [markdown]
# ### Name

# %%
df.Name.head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %% [markdown]
# Each name has a title, which is clearly what matters since it contains information of gender or status. Let's extract the titles from these names.

# %%
df['Title'] = df.Name.map( lambda x: x.split(',')[1].split( '.' )[0].strip())

# inspect the amount of people for each title
df['Title'].value_counts()
# Out:
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Mlle              2
# Ms                2
# Major             2
# Capt              1
# Dona              1
# Don               1
# Lady              1
# Sir               1
# Jonkheer          1
# the Countess      1
# Mme               1
# Name: Title, dtype: int64

# %% [markdown]
# Looks like the main ones are "Master", "Miss", "Mr", "Mrs". Some of the others can be be merged into some of these four categories. For the rest, I'll just call them "Others"

# %%
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace(['Mme','Lady','Ms'], 'Mrs')
df.Title.loc[ (df.Title !=  'Master') & (df.Title !=  'Mr') & (df.Title !=  'Miss') 
             & (df.Title !=  'Mrs')] = 'Others'

# inspect the correlation between Title and Survived
df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.701087
# 2      Mr  0.156673
# 3     Mrs  0.796875
# 4  Others  0.318182

# %%
# inspect the amount of people for each title
df['Title'].value_counts()
# Out:
# Mr        757
# Miss      262
# Mrs       201
# Master     61
# Others     28
# Name: Title, dtype: int64

# %% [markdown]
# Now we can use dummy variables for these titles and drop the original names

# %%
df = pd.concat([df, pd.get_dummies(df['Title'])], axis=1).drop(labels=['Name'], axis=1)

# %% [markdown]
# ### Sex

# %%
# check if there is any NAN
df.Sex.isnull().sum(axis=0)
# Out:
# 0

# %%
# inspect the correlation between Sex and Survived
df[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
# map the two genders to 0 and 1
df.Sex = df.Sex.map({'male':0, 'female':1})

# %% [markdown]
# ### Age

# %%
# check if there is any NAN
df.Age.isnull().sum(axis=0)
# Out:
# 263

# %% [markdown]
# There are 263 missing values! Age can probably be inferred from other features such as Title, Fare, SibSp, Parch. So I decide to come back to Age after I finish inspecting the other features.

# %% [markdown]
# ### SibSp and Parch

# %%
# check if there is any NAN
df.SibSp.isnull().sum(axis=0), df.Parch.isnull().sum(axis=0)
# Out:
# (0, 0)

# %%
# create a new feature "Family"
df['Family'] = df['SibSp'] + df['Parch'] + 1

# inspect the correlation between Family and Survived
df[['Family', 'Survived']].groupby(['Family'], as_index=False).mean()
# Out:
#    Family  Survived
# 0       1  0.303538
# 1       2  0.552795
# 2       3  0.578431
# 3       4  0.724138
# 4       5  0.200000
# 5       6  0.136364
# 6       7  0.333333
# 7       8  0.000000
# 8      11  0.000000

# %%
# inspect the amount of people for each Family size
df['Family'].value_counts()
# Out:
# 1     790
# 2     235
# 3     159
# 4      43
# 6      25
# 5      22
# 7      16
# 11     11
# 8       8
# Name: Family, dtype: int64

# %% [markdown]
# We can see that the survival rate increases with the family size, but not beyond Family = 4. Also, the amount of people in big families is much lower than those in small families. I will combine all the data with Family > 4 into one category. Since people in big families have an even lower survival rate (0.161290) than those who are alone, I decided to map data with Family > 4 to Family = 0, such that the survival rate always increases as Family increases.

# %%
df.Family = df.Family.map(lambda x: 0 if x > 4 else x)
df[['Family', 'Survived']].groupby(['Family'], as_index=False).mean()
# Out:
#    Family  Survived
# 0       0  0.161290
# 1       1  0.303538
# 2       2  0.552795
# 3       3  0.578431
# 4       4  0.724138

# %%
df['Family'].value_counts()
# Out:
# 1    790
# 2    235
# 3    159
# 0     82
# 4     43
# Name: Family, dtype: int64

# %% [markdown]
# ### Ticket

# %%
# check if there is any NAN
df.Ticket.isnull().sum(axis=0)
# Out:
# 0

# %%
df.Ticket.head(20)
# Out:
# 0            A/5 21171
# 1             PC 17599
# 2     STON/O2. 3101282
# 3               113803
# 4               373450
# 5               330877
# 6                17463
# 7               349909
# 8               347742
# 9               237736
# 10             PP 9549
# 11              113783
# 12           A/5. 2151
# 13              347082
# 14              350406
# 15              248706
# 16              382652
# 17              244373
# 18              345763
# 19                2649
# Name: Ticket, dtype: object

# %% [markdown]
# It looks like there are two types of tickets: (1) number (2) letters + number
#
# Ticket names with letters probably represent some special classes. For the numbers, the majority of tickets have their first digit = 1, 2, or 3, which probably also represent different classes. So I just keep the first element (a letter or a single-digit  number) of these ticket names

# %%
df.Ticket = df.Ticket.map(lambda x: x[0])

# inspect the correlation between Ticket and Survived
df[['Ticket', 'Survived']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket  Survived
# 0       1  0.630137
# 1       2  0.464481
# 2       3  0.239203
# 3       4  0.200000
# 4       5  0.000000
# 5       6  0.166667
# 6       7  0.111111
# 7       8  0.000000
# 8       9  1.000000
# 9       A  0.068966
# 10      C  0.340426
# 11      F  0.571429
# 12      L  0.250000
# 13      P  0.646154
# 14      S  0.323077
# 15      W  0.153846

# %%
# inspect the amount of people for each type of tickets
df['Ticket'].value_counts()
# Out:
# 3    429
# 2    278
# 1    210
# P     98
# S     98
# C     77
# A     42
# W     19
# F     13
# 7     13
# 4     11
# 6      9
# L      5
# 5      3
# 9      2
# 8      2
# Name: Ticket, dtype: int64

# %% [markdown]
# We can see that the majority of tickets are indeed "3", "2", and "1", and their corresponding survival rates are "1" > "2" > "3". For the others, the survival rate is low except for "9","C","F","P", and "S". However, "9" and "F" are very small sample. The correlation we see here probably comes from Pclass or Fare, so let's check.

# %%
df[['Ticket', 'Fare']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket        Fare
# 0       1   65.771211
# 1       2   20.235194
# 2       3   15.380682
# 3       4   16.764036
# 4       5   19.262500
# 5       6   19.153711
# 6       7    9.197438
# 7       8    8.397900
# 8       9    7.750000
# 9       A   10.189681
# 10      C   28.152273
# 11      F   24.677246
# 12      L    1.515000
# 13      P  119.698253
# 14      S   17.542900
# 15      W   31.056579

# %%
df[['Ticket', 'Pclass']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket    Pclass
# 0       1  1.147619
# 1       2  2.309353
# 2       3  2.904429
# 3       4  3.000000
# 4       5  2.333333
# 5       6  2.111111
# 6       7  3.000000
# 7       8  3.000000
# 8       9  3.000000
# 9       A  3.000000
# 10      C  2.558442
# 11      F  1.846154
# 12      L  3.000000
# 13      P  1.102041
# 14      S  2.561224
# 15      W  2.315789

# %% [markdown]
# Indeed, there is some relation between Ticket and Fare, or between Ticket and Pclass. Also, one interesting thing is that "P" corresponds to very high Fare and Pcalss (better than "1"). This is an additional information that cannot be seen in other features. So keeping Ticket as a feature might be useful.
#
# I'll come back to Ticket later. I don't further transform it now because its current form might be useful for guessing some missing values in other features.

# %% [markdown]
# ### Fare

# %%
# check if there is any NAN
df.Fare.isnull().sum(axis=0)
# Out:
# 1

# %% [markdown]
# Only one missing value. Fare can probably be inferred from Ticket, Pclass, Cabin and Embarked. Let's see the corresponding values of for these features.

# %%
df.Ticket[df.Fare.isnull()]
# Out:
# 1043    3
# Name: Ticket, dtype: object

# %%
df.Pclass[df.Fare.isnull()]
# Out:
# 1043    3
# Name: Pclass, dtype: int64

# %%
df.Cabin[df.Fare.isnull()]
# Out:
# 1043    NaN
# Name: Cabin, dtype: object

# %%
df.Embarked[df.Fare.isnull()]
# Out:
# 1043    S
# Name: Embarked, dtype: object

# %% [markdown]
# There is no corresponding value for Cabin, so let's look at the relation between Fare and the three features.

# %%
# use boxplot to visualize the distribution of Fare for each Pclass
sns.boxplot('Pclass','Fare',data=df)
plt.ylim(0, 300) # ignore one data point with Fare > 500
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# inspect the correlation between Pclass and Fare
df[['Pclass', 'Fare']].groupby(['Pclass']).mean()
# Out:
#              Fare
# Pclass
# 1       87.508992
# 2       21.179196
# 3       13.302889

# %%
# divide the standard deviation by the mean. A lower ratio means a tighter 
# distribution of Fare in each Pclass
df[['Pclass', 'Fare']].groupby(['Pclass']).std() / df[['Pclass', 'Fare']].groupby(['Pclass']).mean()
# Out:
#             Fare
# Pclass
# 1       0.919302
# 2       0.642476
# 3       0.864050

# %%
# use boxplot to visualize the distribution of Fare for each Ticket
sns.boxplot('Ticket','Fare',data=df)
plt.ylim(0, 300) # ignore one data point with Fare > 500
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# inspect the correlation between Ticket and Fare 
# (we saw this earlier)
df[['Ticket', 'Fare']].groupby(['Ticket']).mean()
# Out:
#               Fare
# Ticket
# 1        65.771211
# 2        20.235194
# 3        15.380682
# 4        16.764036
# 5        19.262500
# 6        19.153711
# 7         9.197438
# 8         8.397900
# 9         7.750000
# A        10.189681
# C        28.152273
# F        24.677246
# L         1.515000
# P       119.698253
# S        17.542900
# W        31.056579

# %%
# divide the standard deviation by the mean. A lower ratio means a tighter 
# distribution of Fare in each Ticket type
df[['Ticket', 'Fare']].groupby(['Ticket']).std() /  df[['Ticket', 'Fare']].groupby(['Ticket']).mean()
# Out:
#             Fare
# Ticket
# 1       0.817411
# 2       1.284139
# 3       1.351244
# 4       0.497578
# 5       0.284367
# 6       0.735873
# 7       0.080078
# 8       0.005961
# 9       0.000000
# A       0.466846
# C       0.736299
# F       0.556023
# L       2.236068
# P       0.944596
# S       1.024639
# W       0.676999

# %%
# use boxplot to visualize the distribution of Fare for each Embarked
sns.boxplot('Embarked','Fare',data=df)
plt.ylim(0, 300) # ignore one data point with Fare > 500
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# inspect the correlation between Embarked and Fare
df[['Embarked', 'Fare']].groupby(['Embarked']).mean()
# Out:
#                Fare
# Embarked
# C         62.336267
# Q         12.409012
# S         27.418824

# %%
# divide the standard deviation by the mean. A lower ratio means a tighter 
# distribution of Fare in each Embarked
df[['Embarked', 'Fare']].groupby(['Embarked']).std() /  df[['Embarked', 'Fare']].groupby(['Embarked']).mean()
# Out:
#               Fare
# Embarked
# C         1.350514
# Q         1.097278
# S         1.352954

# %% [markdown]
# Looks like Fare indeed has correlation with these three features. I'll guess the missing value using the median value of (Pcalss = 3) & (Ticket = 3) & (Embarked = S)

# %%
guess_Fare = df.Fare.loc[ (df.Ticket == '3') & (df.Pclass == 3) & (df.Embarked == 'S')].median()
df.Fare.fillna(guess_Fare , inplace=True)

# inspect the mean Fare values for people who died and survived
df[['Fare', 'Survived']].groupby(['Survived'],as_index=False).mean()
# Out:
#    Survived       Fare
# 0       0.0  22.117887
# 1       1.0  48.395408

# %%
# visualize the distribution of Fare for people who survived and died
grid = sns.FacetGrid(df, hue='Survived', size=4, aspect=1.5)
grid.map(plt.hist, 'Fare', alpha=.5, bins=range(0,210,10))
grid.add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# visualize the correlation between Fare and Survived using a scatter plot
df[['Fare', 'Survived']].groupby(['Fare'],as_index=False).mean().plot.scatter('Fare','Survived')
plt.show()

# %% [markdown]
# We can see that people with lower Fare are less likely to survive. But this is certainly not a smooth curve if we don't bin the data. It would be better to feed machine learning algorithms with intervals of Fare, because using the original Fare values would likely cause over-fitting.

# %%
# bin Fare into five intervals with equal amount of people
df['Fare-bin'] = pd.qcut(df.Fare,5,labels=[1,2,3,4,5]).astype(int)

# inspect the correlation between Fare-bin and Survived
df[['Fare-bin', 'Survived']].groupby(['Fare-bin'], as_index=False).mean()
# Out:
#    Fare-bin  Survived
# 0         1  0.217877
# 1         2  0.201087
# 2         3  0.426901
# 3         4  0.443243
# 4         5  0.645349

# %% [markdown]
# Now the correlation is clear after binning the data!
#
# ### Cabin

# %%
# check if there is any NAN
df.Cabin.isnull().sum(axis=0)
# Out:
# 1014

# %% [markdown]
# This is highly incomplete. We have two choices: (1) map the missing ones to a new cabin category "unknown" (2) just drop this feature. I have tried both and I decided to choose (2)

# %%
df = df.drop(labels=['Cabin'], axis=1)

# %% [markdown]
# ### Embarked

# %%
# check if there is any NAN
df.Embarked.isnull().sum(axis=0)
# Out:
# 2

# %%
df.describe(include=['O']) # S is the most common
# Out:
#        Ticket Embarked Title
# count    1309     1307  1309
# unique     16        3     5
# top         3        S    Mr
# freq      429      914   757

# %%
# fill the NAN
df.Embarked.fillna('S' , inplace=True )

# %%
# inspect the correlation between Embarked and Survived as well as some other features
df[['Embarked', 'Survived','Pclass','Fare', 'Age', 'Sex']].groupby(['Embarked'], as_index=False).mean()
# Out:
#   Embarked  Survived    Pclass       Fare        Age       Sex
# 0        C  0.553571  1.851852  62.336267  32.332170  0.418519
# 1        Q  0.389610  2.894309  12.409012  28.630000  0.487805
# 2        S  0.339009  2.344978  27.512485  29.298151  0.319869

# %% [markdown]
# The survival rate does change between different Embarked values. However, it is due to the changes of other features. For example, people from Embarked = C are more likely to survive because they are generally richer (Pclass, Fare). People from Embarked = S has the lowest survival rate because it has the lowest fraction of female passengers, even though they are a bit richer than people from Embarked = Q.
#
# I therefore decided to drop this feature as well.

# %%
df = df.drop(labels='Embarked', axis=1)

# %% [markdown]
# Now we can go back to **Age** and try to fill the missing values. Let's see how it relates to other features

# %%
# visualize the correlation between Title and Age
grid = sns.FacetGrid(df, col='Title', size=3, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# inspect the mean Age for each Title
df[['Title', 'Age']].groupby(['Title']).mean()
# Out:
#               Age
# Title
# Master   5.482642
# Miss    21.795236
# Mr      32.252151
# Mrs     36.930636
# Others  45.074074

# %%
# inspect the standard deviation of Age for each Title
df[['Title', 'Age']].groupby(['Title']).std()
# Out:
#               Age
# Title
# Master   4.161554
# Miss    12.192794
# Mr      12.422089
# Mrs     12.872625
# Others  11.303253

# %%
# visualize the correlation between Fare-bin and Age
grid = sns.FacetGrid(df, col='Fare-bin', size=3, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# inspect the mean Age for each Fare-bin
df[['Fare-bin', 'Age']].groupby(['Fare-bin']).mean()
# Out:
#                 Age
# Fare-bin
# 1         27.848315
# 2         27.898241
# 3         26.144009
# 4         30.728604
# 5         35.877913

# %%
# inspect the standard deviation of Age for each Fare-bin
df[['Fare-bin', 'Age']].groupby(['Fare-bin']).std()
# Out:
#                 Age
# Fare-bin
# 1         10.812580
# 2         10.995650
# 3         13.523208
# 4         17.466022
# 5         15.150724

# %%
# visualize the correlation between SibSp and Age
grid = sns.FacetGrid(df, col='SibSp', col_wrap=4, size=3.0, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# inspect the mean Age for each SibSp
df[['SibSp', 'Age']].groupby(['SibSp']).mean()
# Out:
#              Age
# SibSp
# 0      30.921766
# 1      31.058071
# 2      23.569444
# 3      16.312500
# 4       8.772727
# 5      10.166667
# 8      14.500000

# %%
# inspect the standard deviation of Age for each SibSp
df[['SibSp', 'Age']].groupby(['SibSp']).std()
# Out:
#              Age
# SibSp
# 0      13.059751
# 1      15.974482
# 2      14.910640
# 3      11.824938
# 4       8.005545
# 5       5.192944
# 8            NaN

# %%
# visualize the correlation between Parch and Age
grid = sns.FacetGrid(df, col='Parch', col_wrap=4, size=3.0, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py:6630: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py:6631: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))

# %%
# inspect the mean Age for each Parch
df[['Parch', 'Age']].groupby(['Parch']).mean()
# Out:
#              Age
# Parch
# 0      31.969401
# 1      24.965625
# 2      18.975979
# 3      38.875000
# 4      47.600000
# 5      39.333333
# 6      41.500000
# 9            NaN

# %%
# inspect the standard deviation of Age for each Parch
df[['Parch', 'Age']].groupby(['Parch']).std()
# Out:
#              Age
# Parch
# 0      12.422617
# 1      18.410885
# 2      14.564066
# 3      16.295815
# 4      14.432602
# 5       1.032796
# 6       2.121320
# 9            NaN

# %% [markdown]
# The change of Age as a function of Title, Fare-bin, or SibSp is quite significant, so I'll use them to guess the missing values. I use a random forest regressor to do this.

# %%
# notice that instead of using Title, we should use its corresponding dummy variables 
df_sub = df[['Age','Master','Miss','Mr','Mrs','Others','Fare-bin','SibSp']]

X_train  = df_sub.dropna().drop('Age', axis=1)
y_train  = df['Age'].dropna()
X_test = df_sub.loc[np.isnan(df.Age)].drop('Age', axis=1)

regressor = RandomForestRegressor(n_estimators = 300)
regressor.fit(X_train, y_train)
y_pred = np.round(regressor.predict(X_test),1)
df.Age.loc[df.Age.isnull()] = y_pred

df.Age.isnull().sum(axis=0) # no more NAN now
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# 0

# %% [markdown]
# And then we still need to bin the data into different Age intervals, for the same reason as Fare

# %%
bins = [ 0, 4, 12, 18, 30, 50, 65, 100] # This is somewhat arbitrary
age_index = (1,2,3,4,5,6,7) #('baby','child','teenager','young','mid-age','over-50','senior')
df['Age-bin'] = pd.cut(df.Age, bins, labels=age_index).astype(int)

df[['Age-bin', 'Survived']].groupby(['Age-bin'],as_index=False).mean()
# Out:
#    Age-bin  Survived
# 0        1  0.675000
# 1        2  0.452381
# 2        3  0.402597
# 3        4  0.315789
# 4        5  0.427083
# 5        6  0.375000
# 6        7  0.125000

# %% [markdown]
# Now we can look at **Ticket** again

# %%
df[['Ticket', 'Survived']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket  Survived
# 0       1  0.630137
# 1       2  0.464481
# 2       3  0.239203
# 3       4  0.200000
# 4       5  0.000000
# 5       6  0.166667
# 6       7  0.111111
# 7       8  0.000000
# 8       9  1.000000
# 9       A  0.068966
# 10      C  0.340426
# 11      F  0.571429
# 12      L  0.250000
# 13      P  0.646154
# 14      S  0.323077
# 15      W  0.153846

# %%
df['Ticket'].value_counts()
# Out:
# 3    429
# 2    278
# 1    210
# P     98
# S     98
# C     77
# A     42
# W     19
# F     13
# 7     13
# 4     11
# 6      9
# L      5
# 5      3
# 9      2
# 8      2
# Name: Ticket, dtype: int64

# %% [markdown]
# The main categories of Ticket are "1", "2", "3", "P", "S", and "C", so I will combine all the others into "4"

# %%
df['Ticket'] = df['Ticket'].replace(['A','W','F','L','5','6','7','8','9'], '4')

# check the correlation again
df[['Ticket', 'Survived']].groupby(['Ticket'], as_index=False).mean()
# Out:
#   Ticket  Survived
# 0      1  0.630137
# 1      2  0.464481
# 2      3  0.239203
# 3      4  0.166667
# 4      C  0.340426
# 5      P  0.646154
# 6      S  0.323077

# %%
# dummy encoding
df = pd.get_dummies(df,columns=['Ticket'])

# %% [markdown]
# ## Modeling and Prediction
#
# Now we can drop the features we don't need and split the data into training and test sets. Then I will use Keras to build a neural network architecture.

# %%
df = df.drop(labels=['SibSp','Parch','Age','Fare','Title'], axis=1)
y_train = df[0:891]['Survived'].values
X_train = df[0:891].drop(['Survived','PassengerId'], axis=1).values
X_test  = df[891:].drop(['Survived','PassengerId'], axis=1).values

# %%
# Initialising the NN
model = Sequential()

# layers
model.add(Dense(9, kernel_initializer = 'uniform', activation = 'relu', input_dim = 17))
model.add(Dense(9, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 162
#
#  dense_1 (Dense)             (None, 9)                 90
#
#  dense_2 (Dense)             (None, 5)                 50
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 308
# Trainable params: 308
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the NN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the NN
model.fit(X_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 28/28 [==============================] - 1s 2ms/step - loss: 0.6919 - accuracy: 0.6162
# Epoch 2/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6886 - accuracy: 0.6162
# Epoch 3/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6818 - accuracy: 0.6162
# Epoch 4/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6633 - accuracy: 0.6162
# Epoch 5/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.6208 - accuracy: 0.6162
# Epoch 6/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5692 - accuracy: 0.6162
# Epoch 7/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5356 - accuracy: 0.6588
# Epoch 8/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5160 - accuracy: 0.7969
# Epoch 9/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.8070
# Epoch 10/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4890 - accuracy: 0.8114
# Epoch 11/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4738 - accuracy: 0.8103
# Epoch 12/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4615 - accuracy: 0.8126
# Epoch 13/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4501 - accuracy: 0.8193
# Epoch 14/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4415 - accuracy: 0.8215
# Epoch 15/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.8283
# Epoch 16/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4302 - accuracy: 0.8283
# Epoch 17/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4261 - accuracy: 0.8316
# Epoch 18/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.8215
# Epoch 19/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4197 - accuracy: 0.8395
# Epoch 20/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4187 - accuracy: 0.8272
# Epoch 21/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4187 - accuracy: 0.8316
# Epoch 22/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4146 - accuracy: 0.8350
# Epoch 23/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4142 - accuracy: 0.8373
# Epoch 24/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4137 - accuracy: 0.8418
# Epoch 25/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4121 - accuracy: 0.8361
# Epoch 26/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4102 - accuracy: 0.8429
# Epoch 27/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4124 - accuracy: 0.8305
# Epoch 28/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4103 - accuracy: 0.8373
# Epoch 29/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4110 - accuracy: 0.8272
# Epoch 30/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4091 - accuracy: 0.8316
# Epoch 31/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4096 - accuracy: 0.8305
# Epoch 32/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4080 - accuracy: 0.8294
# Epoch 33/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4055 - accuracy: 0.8406
# Epoch 34/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4048 - accuracy: 0.8339
# Epoch 35/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8384
# Epoch 36/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4059 - accuracy: 0.8305
# Epoch 37/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4036 - accuracy: 0.8406
# Epoch 38/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4036 - accuracy: 0.8373
# Epoch 39/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4027 - accuracy: 0.8361
# Epoch 40/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.8294
# Epoch 41/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4022 - accuracy: 0.8361
# Epoch 42/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4022 - accuracy: 0.8339
# Epoch 43/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4015 - accuracy: 0.8294
# Epoch 44/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.8384
# Epoch 45/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8406
# Epoch 46/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4009 - accuracy: 0.8361
# Epoch 47/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8384
# Epoch 48/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4036 - accuracy: 0.8373
# Epoch 49/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8283
# Epoch 50/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4017 - accuracy: 0.8384
# Epoch 51/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.8350
# Epoch 52/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3998 - accuracy: 0.8395
# Epoch 53/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4042 - accuracy: 0.8384
# Epoch 54/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4005 - accuracy: 0.8339
# Epoch 55/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3997 - accuracy: 0.8294
# Epoch 56/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4014 - accuracy: 0.8384
# Epoch 57/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3990 - accuracy: 0.8384
# Epoch 58/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.8361
# Epoch 59/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.8395
# Epoch 60/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3985 - accuracy: 0.8294
# Epoch 61/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8361
# Epoch 62/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4002 - accuracy: 0.8406
# Epoch 63/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4002 - accuracy: 0.8328
# Epoch 64/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3978 - accuracy: 0.8339
# Epoch 65/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3985 - accuracy: 0.8328
# Epoch 66/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3991 - accuracy: 0.8328
# Epoch 67/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3985 - accuracy: 0.8305
# Epoch 68/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8339
# Epoch 69/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8373
# Epoch 70/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.8384
# Epoch 71/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3991 - accuracy: 0.8249
# Epoch 72/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3981 - accuracy: 0.8339
# Epoch 73/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3988 - accuracy: 0.8316
# Epoch 74/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3980 - accuracy: 0.8373
# Epoch 75/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3970 - accuracy: 0.8373
# Epoch 76/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3982 - accuracy: 0.8350
# Epoch 77/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3971 - accuracy: 0.8339
# Epoch 78/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3965 - accuracy: 0.8373
# Epoch 79/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3985 - accuracy: 0.8305
# Epoch 80/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8384
# Epoch 81/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.8316
# Epoch 82/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3980 - accuracy: 0.8316
# Epoch 83/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3969 - accuracy: 0.8350
# Epoch 84/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3979 - accuracy: 0.8339
# Epoch 85/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8339
# Epoch 86/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3969 - accuracy: 0.8373
# Epoch 87/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3971 - accuracy: 0.8373
# Epoch 88/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3988 - accuracy: 0.8272
# Epoch 89/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3973 - accuracy: 0.8328
# Epoch 90/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3978 - accuracy: 0.8316
# Epoch 91/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8305
# Epoch 92/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8316
# Epoch 93/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3962 - accuracy: 0.8350
# Epoch 94/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3959 - accuracy: 0.8283
# Epoch 95/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3998 - accuracy: 0.8227
# Epoch 96/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3995 - accuracy: 0.8305
# Epoch 97/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8328
# Epoch 98/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8350
# Epoch 99/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3961 - accuracy: 0.8339
# Epoch 100/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3964 - accuracy: 0.8339
# Epoch 101/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3965 - accuracy: 0.8339
# Epoch 102/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8361
# Epoch 103/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3960 - accuracy: 0.8339
# Epoch 104/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3952 - accuracy: 0.8316
# Epoch 105/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8339
# Epoch 106/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8339
# Epoch 107/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3959 - accuracy: 0.8373
# Epoch 108/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3955 - accuracy: 0.8328
# Epoch 109/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3951 - accuracy: 0.8361
# Epoch 110/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.8294
# Epoch 111/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3948 - accuracy: 0.8350
# Epoch 112/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8350
# Epoch 113/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8350
# Epoch 114/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3955 - accuracy: 0.8361
# Epoch 115/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3948 - accuracy: 0.8316
# Epoch 116/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3957 - accuracy: 0.8361
# Epoch 117/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8294
# Epoch 118/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3964 - accuracy: 0.8384
# Epoch 119/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8350
# Epoch 120/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3953 - accuracy: 0.8316
# Epoch 121/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8361
# Epoch 122/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3960 - accuracy: 0.8361
# Epoch 123/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3935 - accuracy: 0.8305
# Epoch 124/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8395
# Epoch 125/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8361
# Epoch 126/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3942 - accuracy: 0.8339
# Epoch 127/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3935 - accuracy: 0.8328
# Epoch 128/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8328
# Epoch 129/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3939 - accuracy: 0.8316
# Epoch 130/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3939 - accuracy: 0.8328
# Epoch 131/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3932 - accuracy: 0.8339
# Epoch 132/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3951 - accuracy: 0.8361
# Epoch 133/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8395
# Epoch 134/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8305
# Epoch 135/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3957 - accuracy: 0.8373
# Epoch 136/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3943 - accuracy: 0.8339
# Epoch 137/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3945 - accuracy: 0.8283
# Epoch 138/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8350
# Epoch 139/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3931 - accuracy: 0.8305
# Epoch 140/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3942 - accuracy: 0.8350
# Epoch 141/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3946 - accuracy: 0.8316
# Epoch 142/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3961 - accuracy: 0.8305
# Epoch 143/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3976 - accuracy: 0.8339
# Epoch 144/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3948 - accuracy: 0.8316
# Epoch 145/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8328
# Epoch 146/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3943 - accuracy: 0.8350
# Epoch 147/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3964 - accuracy: 0.8316
# Epoch 148/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8328
# Epoch 149/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3932 - accuracy: 0.8339
# Epoch 150/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3955 - accuracy: 0.8350
# Epoch 151/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3930 - accuracy: 0.8339
# Epoch 152/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8395
# Epoch 153/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3931 - accuracy: 0.8328
# Epoch 154/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3926 - accuracy: 0.8373
# Epoch 155/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8361
# Epoch 156/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8361
# Epoch 157/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3926 - accuracy: 0.8328
# Epoch 158/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3923 - accuracy: 0.8339
# Epoch 159/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3942 - accuracy: 0.8373
# Epoch 160/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3919 - accuracy: 0.8316
# Epoch 161/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3963 - accuracy: 0.8339
# Epoch 162/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8294
# Epoch 163/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8373
# Epoch 164/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3929 - accuracy: 0.8350
# Epoch 165/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3934 - accuracy: 0.8350
# Epoch 166/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3933 - accuracy: 0.8328
# Epoch 167/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3941 - accuracy: 0.8373
# Epoch 168/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3942 - accuracy: 0.8339
# Epoch 169/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3921 - accuracy: 0.8339
# Epoch 170/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.8361
# Epoch 171/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.8350
# Epoch 172/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.8395
# Epoch 173/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8373
# Epoch 174/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3914 - accuracy: 0.8339
# Epoch 175/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.8328
# Epoch 176/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3920 - accuracy: 0.8305
# Epoch 177/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3912 - accuracy: 0.8350
# Epoch 178/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.8361
# Epoch 179/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3932 - accuracy: 0.8339
# Epoch 180/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3934 - accuracy: 0.8305
# Epoch 181/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3919 - accuracy: 0.8316
# Epoch 182/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3913 - accuracy: 0.8294
# Epoch 183/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3913 - accuracy: 0.8350
# Epoch 184/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.8361
# Epoch 185/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3913 - accuracy: 0.8328
# Epoch 186/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3915 - accuracy: 0.8316
# Epoch 187/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3916 - accuracy: 0.8328
# Epoch 188/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8350
# Epoch 189/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3915 - accuracy: 0.8339
# Epoch 190/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3915 - accuracy: 0.8373
# Epoch 191/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8339
# Epoch 192/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3942 - accuracy: 0.8305
# Epoch 193/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8384
# Epoch 194/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3927 - accuracy: 0.8328
# Epoch 195/200
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3918 - accuracy: 0.8339
# Epoch 196/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8350
# Epoch 197/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3908 - accuracy: 0.8350
# Epoch 198/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3909 - accuracy: 0.8328
# Epoch 199/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3904 - accuracy: 0.8294
# Epoch 200/200
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3931 - accuracy: 0.8406

# %% [markdown]
# We can now produce the prediction.

# %%
y_pred = model.predict(X_test)
y_final = (y_pred > 0.5).astype(int).reshape(X_test.shape[0])

output = pd.DataFrame({'PassengerId': df_test['PassengerId'], 'Survived': y_final})
output.to_csv('/content/drive/MyDrive/Coding_DOJO-Data_Science_Bootcamp/04_AdvancedML/Titanic Dataset/prediction.csv', index=False)
